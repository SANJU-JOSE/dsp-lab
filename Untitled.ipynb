# %% [markdown]
# Random signals: A random signal of length N with samples uniformly distributed in the
# interval 0,1) can be generated by using the command x =np.random.random_sample(N). Generate and display a random signal of length 100 .whose elements are uniformly distributed in the interval [−2, 2)
#
# 2)Likewise, a random signal x[n] of length N with samples normally distributed with zero mean
# and unity std. dev. can be generated by using the following command x = np.random.normal(0.0, 1.0, N)
# Generate and display a Gaussian random signal of length 75 whose elements are normally
# distributed with zero mean and a variance of 3. (Check your result with np.mean() and np.var()
#
# 3)Generate and plot a sinewave corrupted with zero mean Gaussian noise.
# t= np.arange(0, 2, .01)
# signal = np.sin(2*np.pi*t)
# noise = np.random.normal(0, 0.1, t.size)
# noisy_signal = signal + noise
# plt.plot(noisy_signal);
# Plot the noisy signal for various values of std dev for the noise

# %%
import numpy as np
import matplotlib.pyplot as plt
y=4*np.random.random_sample(100)-2
plt.plot(y)
plt.show()

# %%
x=np.random.normal(0.0,np.sqrt(3),75)
plt.plot(x)
print("mean = ",np.mean(x))
print("variance =",np.var(x))
# Out:
# mean =  0.0015714997032272274
# variance = 2.9204907721197766

# %%
t=np.arange(0,2,0.01)
signal = np.sin(2*np.pi*t)
noise1 = np.random.normal(0, 0.1, t.size)
noisy_signal1 = signal + noise1
plt.subplot(4,1,1)
plt.plot(noisy_signal1)
noise2 = np.random.normal(0, 0.25, t.size)
noisy_signal2 = signal + noise2
plt.subplot(4,1,2)
plt.plot(noisy_signal2)
noise3 = np.random.normal(0, 0.5, t.size)
noisy_signal3 = signal + noise3
plt.subplot(4,1,3)
plt.plot(noisy_signal3)
noise4 = np.random.normal(0, 0.75, t.size)
noisy_signal4= signal + noise4
plt.subplot(4,1,4)
plt.plot(noisy_signal4)
plt.show()
